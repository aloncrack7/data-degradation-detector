# %% [markdown]
# # Testing univariate

# %% [markdown]
# ## Import libararies

# %%
import pandas as pd
from data_degradation_detector import univariate as uv
import matplotlib.pyplot as plt
import numpy as np
import importlib
importlib.reload(uv)
# Out:
# <module 'data_degradation_detector.univariate' from 'c:\\Users\\alonm\\Documents\\Programacion\\data-degradation-detector\\data_degradation_detector\\univariate.py'>

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv("data/WineQT.csv")
df = df.drop(columns=['quality', 'Id'], axis=1)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1138     11.0
# 1139      9.5
# 1140     10.5
# 1141     11.2
# 1142     10.2
#
# [1143 rows x 11 columns]

# %% [markdown]
# ## Test the module

# %%
print(uv.get_distribution_descriptors_all_columns(df))
# Out:
# {'fixed acidity': DistributionDescriptors(mean=8.311111111111112, std=1.74759501716954, min_val=4.6, max_val=15.9, q1=7.1, q2=7.9, q3=9.1), 'volatile acidity': DistributionDescriptors(mean=0.5313385826771653, std=0.1796331930225245, min_val=0.12, max_val=1.58, q1=0.3925, q2=0.52, q3=0.64), 'citric acid': DistributionDescriptors(mean=0.2683639545056868, std=0.19668585234821898, min_val=0.0, max_val=1.0, q1=0.09, q2=0.25, q3=0.42), 'residual sugar': DistributionDescriptors(mean=2.5321522309711284, std=1.3559174666826799, min_val=0.9, max_val=15.5, q1=1.9, q2=2.2, q3=2.6), 'chlorides': DistributionDescriptors(mean=0.08693263342082239, std=0.04726733795238057, min_val=0.012, max_val=0.611, q1=0.07, q2=0.079, q3=0.09), 'free sulfur dioxide': DistributionDescriptors(mean=15.615485564304462, std=10.250486123430822, min_val=1.0, max_val=68.0, q1=7.0, q2=13.0, q3=21.0), 'total sulfur dioxide': DistributionDescriptors(mean=45.91469816272966, std=32.78213030734311, min_val=6.0, max_val=289.0, q1=21.0, q2=37.0, q3=61.0), 'density': DistributionDescriptors(mean=0.9967304111986001, std=0.0019250671302545696, min_val=0.99007, max_val=1.00369, q1=0.99557, q2=0.99668, q3=0.997845), 'pH': DistributionDescriptors(mean=3.3110148731408575, std=0.15666405977275194, min_val=2.74, max_val=4.01, q1=3.205, q2=3.31, q3=3.4), 'sulphates': DistributionDescriptors(mean=0.6577077865266842, std=0.1703987144670741, min_val=0.33, max_val=2.0, q1=0.55, q2=0.62, q3=0.73), 'alcohol': DistributionDescriptors(mean=10.442111402741325, std=1.0821956098764445, min_val=8.4, max_val=14.9, q1=9.5, q2=10.2, q3=11.1)}

# %%
uv.plot_distribution_descriptors_all_columns(df)

# %%
df1 = df.iloc[:len(df)//2].reset_index(drop=True)
df2 = df.iloc[len(df)//2:].reset_index(drop=True)

# %%
dfs = np.array_split(df, 10)
uv.descriptor_evolution_all_columns(dfs)
# Out:
# c:\Users\alonm\Documents\Programacion\data-degradation-detector\venv\Lib\site-packages\numpy\_core\fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
